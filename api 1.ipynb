# %%
from pandas.io.json import json_normalize
import os
from dotenv import load_dotenv
import requests
import pandas as pd
load_dotenv()

token = os.getenv("API_KEY")

# %%
def requestsportradar(year):
    token = os.getenv("API_KEY")
    if not token:
        raise ValueError("You must set a sportradar token")
    
    baseUrl = "https://api.sportradar.us/golf"
    endpoint = f"-t2/seasontd/pga/{year}/players/statistics.json"
    url = baseUrl+endpoint
    print(f"Requesting data from {url}")
    params = {
        "api_key": f"{token}"
    }
    res = requests.get(url,params=params)
    print(res)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    return res.json()

# %%
'''
def requestsportradar(year):
    token = os.getenv("API_KEY")
    if not token:
        raise ValueError("You must set a sportradar token")
    
    baseUrl = "https://api.sportradar.us/golf"
    endpoint = f"-t2/players/wgr/{year}/rankings.json"
    url = baseUrl+endpoint
    print(f"Requesting data from {url}")
    params = {
        "api_key": f"{token}"
    }
    res = requests.get(url,params=params)
    print(res)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    return res.json()
'''
# Out:
# '\ndef requestsportradar(year):\n    token = os.getenv("API_KEY")\n    if not token:\n        raise ValueError("You must set a sportradar token")\n    \n    baseUrl = "https://api.sportradar.us/golf"\n    endpoint = f"-t2/players/wgr/{year}/rankings.json"\n    url = baseUrl+endpoint\n    print(f"Requesting data from {url}")\n    params = {\n        "api_key": f"{token}"\n    }\n    res = requests.get(url,params=params)\n    print(res)\n    if res.status_code != 200:\n        print(res.text)\n        raise ValueError("Bad Response")\n    return res.json()\n'

# %%
api=requestsportradar(2018)
api
# Out:
# Requesting data from https://api.sportradar.us/golf-t2/seasontd/pga/2018/players/statistics.json
# <Response [200]>
# {'players': [{'country': 'UNITED STATES',
#    'first_name': 'D.A.',
#    'id': 'f5b4cf34-e047-436d-8475-3a62f3bc06ac',
#    'last_name': 'Points',
#    'statistics': {'birdies_per_round': 3.07,
#     'cuts': 19,
#     'cuts_made': 6,
#     'drive_acc': 60.47,
#     'drive_avg': 280.8,
#     'earnings': 377265.0,
#     'earnings_rank': 173,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 60.2,
#     'hole_proximity_avg': '36\' 6"',
#     'holes_per_eagle': 122.0,
#     'points': 0,
#     'points_rank': 176,
#     'putt_avg': 1.778,
#     'sand_saves_pct': 57.66,
#     'scoring_avg': 73.019,
#     'scrambling_pct': 53.32,
#     'second_place': 0,
#     'strokes_gained': 0.11,
#     'strokes_gained_tee_green': -1.559,
#     'strokes_gained_total': -1.449,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 1,
#     'total_driving': 297,
#     'withdrawals': 0,
#     'world_rank': 380}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Harold',
#    'id': '19564b63-f9c8-4263-a689-3135b7755631',
#    'last_name': 'Varner III',
#    'statistics': {'birdies_per_round': 3.45,
#     'cuts': 9,
#     'cuts_made': 18,
#     'drive_acc': 58.73,
#     'drive_avg': 308.2,
#     'earnings': 1223064.0,
#     'earnings_rank': 100,
#     'events_played': 27,
#     'first_place': 0,
#     'gir_pct': 68.07,
#     'hole_proximity_avg': '36\' 8"',
#     'holes_per_eagle': 160.2,
#     'points': 0,
#     'points_rank': 107,
#     'putt_avg': 1.785,
#     'sand_saves_pct': 52.0,
#     'scoring_avg': 70.971,
#     'scrambling_pct': 59.0,
#     'second_place': 0,
#     'strokes_gained': -0.026,
#     'strokes_gained_tee_green': 0.209,
#     'strokes_gained_total': 0.183,
#     'third_place': 0,
#     'top_10': 3,
#     'top_25': 5,
#     'total_driving': 151,
#     'withdrawals': 0,
#     'world_rank': 167}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Sam',
#    'id': '229faa9c-fc01-46bb-a8cb-f6b0310a8cef',
#    'last_name': 'Ryder',
#    'statistics': {'birdies_per_round': 3.84,
#     'cuts': 11,
#     'cuts_made': 15,
#     'drive_acc': 66.91,
#     'drive_avg': 297.3,
#     'earnings': 1046166.0,
#     'earnings_rank': 113,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 72.08,
#     'hole_proximity_avg': '34\' 4"',
#     'holes_per_eagle': 205.7,
#     'points': 0,
#     'points_rank': 101,
#     'putt_avg': 1.785,
#     'sand_saves_pct': 43.48,
#     'scoring_avg': 70.914,
#     'scrambling_pct': 56.47,
#     'second_place': 1,
#     'strokes_gained': -0.349,
#     'strokes_gained_tee_green': 0.503,
#     'strokes_gained_total': 0.154,
#     'third_place': 0,
#     'top_10': 3,
#     'top_25': 3,
#     'total_driving': 107,
#     'withdrawals': 0,
#     'world_rank': 192}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Tony',
#    'id': 'f33d746b-8e14-4325-a4e1-81d6f983b163',
#    'last_name': 'Finau',
#    'statistics': {'birdies_per_round': 4.13,
#     'cuts': 3,
#     'cuts_made': 25,
#     'drive_acc': 54.55,
#     'drive_avg': 315.3,
#     'earnings': 5620138.0,
#     'earnings_rank': 7,
#     'events_played': 28,
#     'first_place': 0,
#     'gir_pct': 70.51,
#     'hole_proximity_avg': '35\' 9"',
#     'holes_per_eagle': 110.3,
#     'points': 1732.0,
#     'points_rank': 6,
#     'putt_avg': 1.736,
#     'sand_saves_pct': 44.51,
#     'scoring_avg': 69.52,
#     'scrambling_pct': 58.32,
#     'second_place': 3,
#     'strokes_gained': 0.175,
#     'strokes_gained_tee_green': 1.172,
#     'strokes_gained_total': 1.346,
#     'third_place': 0,
#     'top_10': 11,
#     'top_25': 19,
#     'total_driving': 184,
#     'withdrawals': 0,
#     'world_rank': 17}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Scott',
#    'id': '72b41f76-a9a1-4ff9-8364-b8a21129bd54',
#    'last_name': 'Piercy',
#    'statistics': {'birdies_per_round': 3.66,
#     'cuts': 7,
#     'cuts_made': 17,
#     'drive_acc': 65.1,
#     'drive_avg': 296.1,
#     'earnings': 1882337.0,
#     'earnings_rank': 64,
#     'events_played': 26,
#     'first_place': 1,
#     'gir_pct': 70.61,
#     'hole_proximity_avg': '35\' 6"',
#     'holes_per_eagle': 288.0,
#     'points': 0,
#     'points_rank': 68,
#     'putt_avg': 1.788,
#     'sand_saves_pct': 43.7,
#     'scoring_avg': 70.736,
#     'scrambling_pct': 56.22,
#     'second_place': 0,
#     'strokes_gained': -0.591,
#     'strokes_gained_tee_green': 0.859,
#     'strokes_gained_total': 0.268,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 8,
#     'total_driving': 134,
#     'withdrawals': 1,
#     'world_rank': 247}},
#   {'country': 'NORTHERN IRELAND',
#    'first_name': 'Rory',
#    'id': 'da226913-b804-48de-adbf-96e956eb75ac',
#    'last_name': 'McIlroy',
#    'statistics': {'birdies_per_round': 4.0,
#     'cuts': 4,
#     'cuts_made': 14,
#     'drive_acc': 55.5,
#     'drive_avg': 319.8,
#     'earnings': 4410296.0,
#     'earnings_rank': 14,
#     'events_played': 18,
#     'first_place': 1,
#     'gir_pct': 66.48,
#     'hole_proximity_avg': '34\' 7"',
#     'holes_per_eagle': 122.0,
#     'points': 602.0,
#     'points_rank': 13,
#     'putt_avg': 1.735,
#     'sand_saves_pct': 54.0,
#     'scoring_avg': 69.303,
#     'scrambling_pct': 64.61,
#     'second_place': 1,
#     'strokes_gained': 0.092,
#     'strokes_gained_tee_green': 1.376,
#     'strokes_gained_total': 1.468,
#     'third_place': 0,
#     'top_10': 7,
#     'top_25': 11,
#     'total_driving': 166,
#     'withdrawals': 0,
#     'world_rank': 5}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Ethan',
#    'id': '69630ce8-f1f1-4ce4-a2ed-bec526164e5c',
#    'last_name': 'Tracy',
#    'statistics': {'birdies_per_round': 3.34,
#     'cuts': 11,
#     'cuts_made': 12,
#     'drive_acc': 60.25,
#     'drive_avg': 299.0,
#     'earnings': 364493.0,
#     'earnings_rank': 175,
#     'events_played': 23,
#     'first_place': 0,
#     'gir_pct': 64.87,
#     'hole_proximity_avg': '36\' 4"',
#     'holes_per_eagle': 122.4,
#     'points': 0,
#     'points_rank': 177,
#     'putt_avg': 1.778,
#     'sand_saves_pct': 34.86,
#     'scoring_avg': 72.038,
#     'scrambling_pct': 54.88,
#     'second_place': 0,
#     'strokes_gained': -0.026,
#     'strokes_gained_tee_green': -0.786,
#     'strokes_gained_total': -0.813,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 2,
#     'total_driving': 185,
#     'withdrawals': 0,
#     'world_rank': 732}},
#   {'country': 'NORTHERN IRELAND',
#    'first_name': 'Graeme',
#    'id': 'a5ac26e5-464f-457f-a24c-f414cf7a2da3',
#    'last_name': 'McDowell',
#    'statistics': {'birdies_per_round': 3.34,
#     'cuts': 7,
#     'cuts_made': 13,
#     'drive_acc': 64.44,
#     'drive_avg': 293.2,
#     'earnings': 581024.0,
#     'earnings_rank': 148,
#     'events_played': 20,
#     'first_place': 0,
#     'gir_pct': 64.42,
#     'hole_proximity_avg': '37\' 7"',
#     'holes_per_eagle': 265.5,
#     'points': 0,
#     'points_rank': 144,
#     'putt_avg': 1.79,
#     'sand_saves_pct': 47.32,
#     'scoring_avg': 71.001,
#     'scrambling_pct': 60.82,
#     'second_place': 0,
#     'strokes_gained': 0.489,
#     'strokes_gained_tee_green': 0.216,
#     'strokes_gained_total': 0.704,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 4,
#     'total_driving': 173,
#     'withdrawals': 0,
#     'world_rank': 208}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Bill',
#    'id': 'a9eb0570-9edd-4de7-8886-f95430d47550',
#    'last_name': 'Haas',
#    'statistics': {'birdies_per_round': 3.05,
#     'cuts': 11,
#     'cuts_made': 14,
#     'drive_acc': 56.35,
#     'drive_avg': 296.3,
#     'earnings': 638414.0,
#     'earnings_rank': 142,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 65.48,
#     'hole_proximity_avg': '37\' 2"',
#     'holes_per_eagle': 190.3,
#     'points': 0,
#     'points_rank': 152,
#     'putt_avg': 1.807,
#     'sand_saves_pct': 55.75,
#     'scoring_avg': 71.028,
#     'scrambling_pct': 61.38,
#     'second_place': 0,
#     'strokes_gained': -0.131,
#     'strokes_gained_tee_green': 0.142,
#     'strokes_gained_total': 0.01,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 3,
#     'total_driving': 250,
#     'withdrawals': 0,
#     'world_rank': 151}},
#   {'country': 'AUSTRALIA',
#    'first_name': 'Stuart',
#    'id': '5e8f5e5f-d761-4e22-b1de-2d1b1af6ce8a',
#    'last_name': 'Appleby',
#    'statistics': {'birdies_per_round': 3.23,
#     'cuts': 7,
#     'cuts_made': 5,
#     'drive_acc': 67.78,
#     'drive_avg': 280.5,
#     'earnings': 175235.0,
#     'earnings_rank': 199,
#     'events_played': 12,
#     'first_place': 0,
#     'gir_pct': 58.7,
#     'hole_proximity_avg': '35\' 3"',
#     'holes_per_eagle': 270.0,
#     'points': 0,
#     'points_rank': 197,
#     'putt_avg': 1.748,
#     'sand_saves_pct': 59.32,
#     'scoring_avg': 71.739,
#     'scrambling_pct': 64.57,
#     'second_place': 0,
#     'strokes_gained': -0.019,
#     'strokes_gained_tee_green': -0.115,
#     'strokes_gained_total': -0.135,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 857}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Harris',
#    'id': '7e11058b-ce7b-4efa-8963-2e48c683ff5b',
#    'last_name': 'English',
#    'statistics': {'birdies_per_round': 3.6,
#     'cuts': 20,
#     'cuts_made': 11,
#     'drive_acc': 58.99,
#     'drive_avg': 302.4,
#     'earnings': 799450.0,
#     'earnings_rank': 128,
#     'events_played': 31,
#     'first_place': 0,
#     'gir_pct': 63.32,
#     'hole_proximity_avg': '38\' 9"',
#     'holes_per_eagle': 156.0,
#     'points': 0,
#     'points_rank': 125,
#     'putt_avg': 1.764,
#     'sand_saves_pct': 44.67,
#     'scoring_avg': 71.162,
#     'scrambling_pct': 57.86,
#     'second_place': 0,
#     'strokes_gained': 0.222,
#     'strokes_gained_tee_green': -0.406,
#     'strokes_gained_total': -0.184,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 6,
#     'total_driving': 174,
#     'withdrawals': 0,
#     'world_rank': 285}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Brian',
#    'id': '92544280-0438-4f43-a5f3-f3a21ea55157',
#    'last_name': 'Harman',
#    'statistics': {'birdies_per_round': 3.73,
#     'cuts': 3,
#     'cuts_made': 22,
#     'drive_acc': 66.36,
#     'drive_avg': 292.0,
#     'earnings': 2733463.0,
#     'earnings_rank': 34,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 67.89,
#     'hole_proximity_avg': '36\' 0"',
#     'holes_per_eagle': 270.0,
#     'points': 0,
#     'points_rank': 48,
#     'putt_avg': 1.761,
#     'sand_saves_pct': 47.45,
#     'scoring_avg': 70.536,
#     'scrambling_pct': 57.55,
#     'second_place': 0,
#     'strokes_gained': 0.363,
#     'strokes_gained_tee_green': -0.123,
#     'strokes_gained_total': 0.24,
#     'third_place': 1,
#     'top_10': 8,
#     'top_25': 11,
#     'total_driving': 161,
#     'withdrawals': 0,
#     'world_rank': 38}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Richy',
#    'id': '325e7b91-03b8-4013-bd77-f476303e7d94',
#    'last_name': 'Werenski',
#    'statistics': {'birdies_per_round': 3.41,
#     'cuts': 15,
#     'cuts_made': 17,
#     'drive_acc': 65.16,
#     'drive_avg': 292.2,
#     'earnings': 1081283.0,
#     'earnings_rank': 110,
#     'events_played': 32,
#     'first_place': 0,
#     'gir_pct': 67.72,
#     'hole_proximity_avg': '35\' 0"',
#     'holes_per_eagle': 150.5,
#     'points': 0,
#     'points_rank': 110,
#     'putt_avg': 1.78,
#     'sand_saves_pct': 43.36,
#     'scoring_avg': 71.185,
#     'scrambling_pct': 57.55,
#     'second_place': 1,
#     'strokes_gained': -0.117,
#     'strokes_gained_tee_green': 0.072,
#     'strokes_gained_total': -0.045,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 6,
#     'total_driving': 170,
#     'withdrawals': 0,
#     'world_rank': 196}},
#   {'country': 'SOUTH KOREA',
#    'first_name': 'Whee',
#    'id': 'fbd310a5-61d2-48e2-9a75-8f57fc3c14f1',
#    'last_name': 'Kim',
#    'statistics': {'birdies_per_round': 3.62,
#     'cuts': 14,
#     'cuts_made': 16,
#     'drive_acc': 61.11,
#     'drive_avg': 285.8,
#     'earnings': 1920340.0,
#     'earnings_rank': 62,
#     'events_played': 30,
#     'first_place': 0,
#     'gir_pct': 63.55,
#     'hole_proximity_avg': '34\' 10"',
#     'holes_per_eagle': 160.2,
#     'points': 0,
#     'points_rank': 72,
#     'putt_avg': 1.744,
#     'sand_saves_pct': 61.82,
#     'scoring_avg': 71.477,
#     'scrambling_pct': 58.56,
#     'second_place': 2,
#     'strokes_gained': 0.427,
#     'strokes_gained_tee_green': -0.864,
#     'strokes_gained_total': -0.437,
#     'third_place': 0,
#     'top_10': 3,
#     'top_25': 5,
#     'total_driving': 277,
#     'withdrawals': 0,
#     'world_rank': 112}},
#   {'country': 'AUSTRALIA',
#    'first_name': 'Geoff',
#    'id': 'd011a6b4-f8c8-4c45-9578-18673407b257',
#    'last_name': 'Ogilvy',
#    'statistics': {'birdies_per_round': 2.81,
#     'cuts': 14,
#     'cuts_made': 4,
#     'drive_acc': 63.33,
#     'drive_avg': 287.6,
#     'earnings': 93947.0,
#     'earnings_rank': 211,
#     'events_played': 18,
#     'first_place': 0,
#     'gir_pct': 62.27,
#     'hole_proximity_avg': '40\' 7"',
#     'holes_per_eagle': 193.5,
#     'points': 0,
#     'points_rank': 207,
#     'putt_avg': 1.828,
#     'sand_saves_pct': 43.06,
#     'scoring_avg': 72.605,
#     'scrambling_pct': 53.42,
#     'second_place': 0,
#     'strokes_gained': -0.178,
#     'strokes_gained_tee_green': -1.541,
#     'strokes_gained_total': -1.719,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 678}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Smylie',
#    'id': '1405a98f-75ba-44da-8af9-f9f9db50768f',
#    'last_name': 'Kaufman',
#    'statistics': {'birdies_per_round': 2.7,
#     'cuts': 18,
#     'cuts_made': 3,
#     'drive_acc': 40.85,
#     'drive_avg': 297.1,
#     'earnings': 201136.0,
#     'earnings_rank': 194,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 50.83,
#     'hole_proximity_avg': '41\' 8"',
#     'holes_per_eagle': 282.0,
#     'points': 0,
#     'points_rank': 200,
#     'putt_avg': 1.802,
#     'sand_saves_pct': 42.86,
#     'scoring_avg': 74.891,
#     'scrambling_pct': 47.12,
#     'second_place': 0,
#     'strokes_gained': -0.398,
#     'strokes_gained_tee_green': -3.586,
#     'strokes_gained_total': -3.984,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 1,
#     'withdrawals': 1,
#     'world_rank': 545}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Steve',
#    'id': '14e4ad95-a9f7-4db9-98a3-070aac024b8d',
#    'last_name': 'Marino',
#    'statistics': {'birdies_per_round': 3.41,
#     'cuts': 2,
#     'cuts_made': 3,
#     'drive_acc': 67.65,
#     'drive_avg': 298.7,
#     'earnings': 76616.0,
#     'earnings_rank': 220,
#     'events_played': 6,
#     'first_place': 0,
#     'gir_pct': 68.95,
#     'hole_proximity_avg': '34\' 7"',
#     'holes_per_eagle': 102.0,
#     'points': 0,
#     'points_rank': 216,
#     'putt_avg': 1.81,
#     'sand_saves_pct': 43.48,
#     'scoring_avg': 71.374,
#     'scrambling_pct': 50.53,
#     'second_place': 0,
#     'strokes_gained': -0.483,
#     'strokes_gained_tee_green': -0.127,
#     'strokes_gained_total': -0.611,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 1,
#     'world_rank': 752}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Jamie',
#    'id': '6fc571b9-d66d-424a-bcde-71ab62e4a35e',
#    'last_name': 'Lovemark',
#    'statistics': {'birdies_per_round': 3.76,
#     'cuts': 6,
#     'cuts_made': 20,
#     'drive_acc': 56.92,
#     'drive_avg': 303.2,
#     'earnings': 1377286.0,
#     'earnings_rank': 93,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 64.65,
#     'hole_proximity_avg': '37\' 9"',
#     'holes_per_eagle': 198.0,
#     'points': 0,
#     'points_rank': 85,
#     'putt_avg': 1.751,
#     'sand_saves_pct': 53.33,
#     'scoring_avg': 70.734,
#     'scrambling_pct': 61.07,
#     'second_place': 0,
#     'strokes_gained': 0.01,
#     'strokes_gained_tee_green': 0.378,
#     'strokes_gained_total': 0.388,
#     'third_place': 0,
#     'top_10': 3,
#     'top_25': 8,
#     'total_driving': 189,
#     'withdrawals': 0,
#     'world_rank': 125}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Jonathan',
#    'id': '3754ec25-9f1b-427f-9c66-22d399d70c0a',
#    'last_name': 'Randolph',
#    'statistics': {'birdies_per_round': 3.17,
#     'cuts': 12,
#     'cuts_made': 11,
#     'drive_acc': 62.18,
#     'drive_avg': 289.4,
#     'earnings': 453328.0,
#     'earnings_rank': 162,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 60.43,
#     'hole_proximity_avg': '38\' 4"',
#     'holes_per_eagle': 292.5,
#     'points': 0,
#     'points_rank': 174,
#     'putt_avg': 1.789,
#     'sand_saves_pct': 54.03,
#     'scoring_avg': 71.945,
#     'scrambling_pct': 59.83,
#     'second_place': 0,
#     'strokes_gained': 0.115,
#     'strokes_gained_tee_green': -0.992,
#     'strokes_gained_total': -0.877,
#     'third_place': 1,
#     'top_10': 1,
#     'top_25': 1,
#     'total_driving': 251,
#     'withdrawals': 2,
#     'world_rank': 482}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Brendan',
#    'id': '5003f675-818b-410a-9f2e-1a860d152900',
#    'last_name': 'Steele',
#    'statistics': {'birdies_per_round': 3.48,
#     'cuts': 6,
#     'cuts_made': 16,
#     'drive_acc': 60.0,
#     'drive_avg': 310.6,
#     'earnings': 2291128.0,
#     'earnings_rank': 50,
#     'events_played': 22,
#     'first_place': 1,
#     'gir_pct': 69.66,
#     'hole_proximity_avg': '37\' 3"',
#     'holes_per_eagle': 172.3,
#     'points': 0,
#     'points_rank': 56,
#     'putt_avg': 1.806,
#     'sand_saves_pct': 48.42,
#     'scoring_avg': 71.021,
#     'scrambling_pct': 54.07,
#     'second_place': 0,
#     'strokes_gained': -0.465,
#     'strokes_gained_tee_green': 0.544,
#     'strokes_gained_total': 0.079,
#     'third_place': 1,
#     'top_10': 3,
#     'top_25': 7,
#     'total_driving': 131,
#     'withdrawals': 0,
#     'world_rank': 84}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Bryson',
#    'id': '0096b26b-fc25-4fcf-90b9-4b796e3f6c5a',
#    'last_name': 'DeChambeau',
#    'statistics': {'birdies_per_round': 4.2,
#     'cuts': 2,
#     'cuts_made': 22,
#     'drive_acc': 61.9,
#     'drive_avg': 305.5,
#     'earnings': 8094489.0,
#     'earnings_rank': 4,
#     'events_played': 26,
#     'first_place': 3,
#     'gir_pct': 70.1,
#     'hole_proximity_avg': '34\' 4"',
#     'holes_per_eagle': 128.8,
#     'points': 2188.0,
#     'points_rank': 3,
#     'putt_avg': 1.754,
#     'sand_saves_pct': 49.65,
#     'scoring_avg': 69.646,
#     'scrambling_pct': 60.75,
#     'second_place': 1,
#     'strokes_gained': 0.291,
#     'strokes_gained_tee_green': 1.276,
#     'strokes_gained_total': 1.567,
#     'third_place': 1,
#     'top_10': 9,
#     'top_25': 14,
#     'total_driving': 118,
#     'withdrawals': 2,
#     'world_rank': 7}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Heath',
#    'id': '3621f509-c376-4af1-b1b6-af96c3051463',
#    'last_name': 'Slocum',
#    'statistics': {'birdies_per_round': 3.0,
#     'cuts': 3,
#     'cuts_made': 2,
#     'drive_acc': 75.0,
#     'drive_avg': 268.9,
#     'earnings': 37814.0,
#     'earnings_rank': 233,
#     'events_played': 5,
#     'first_place': 0,
#     'gir_pct': 63.33,
#     'hole_proximity_avg': '37\' 8"',
#     'points': 0,
#     'points_rank': 225,
#     'putt_avg': 1.877,
#     'sand_saves_pct': 50.0,
#     'scoring_avg': 73.91,
#     'scrambling_pct': 60.61,
#     'second_place': 0,
#     'strokes_gained': -0.576,
#     'strokes_gained_tee_green': -0.692,
#     'strokes_gained_total': -1.268,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 1557}},
#   {'country': 'IRELAND',
#    'first_name': 'Seamus',
#    'id': '7da9d857-1f6b-4d76-9396-592d5d9d65eb',
#    'last_name': 'Power',
#    'statistics': {'birdies_per_round': 3.64,
#     'cuts': 12,
#     'cuts_made': 15,
#     'drive_acc': 55.19,
#     'drive_avg': 302.6,
#     'earnings': 791018.0,
#     'earnings_rank': 130,
#     'events_played': 28,
#     'first_place': 0,
#     'gir_pct': 65.17,
#     'hole_proximity_avg': '37\' 5"',
#     'holes_per_eagle': 351.0,
#     'points': 0,
#     'points_rank': 114,
#     'putt_avg': 1.778,
#     'sand_saves_pct': 60.94,
#     'scoring_avg': 70.869,
#     'scrambling_pct': 63.8,
#     'second_place': 0,
#     'strokes_gained': 0.498,
#     'strokes_gained_tee_green': -0.319,
#     'strokes_gained_total': 0.178,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 6,
#     'total_driving': 215,
#     'withdrawals': 0,
#     'world_rank': 321}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Denny',
#    'id': '6787bd96-6bf0-4297-b819-85025f81a3a9',
#    'last_name': 'McCarthy',
#    'statistics': {'birdies_per_round': 3.49,
#     'cuts': 9,
#     'cuts_made': 13,
#     'drive_acc': 63.45,
#     'drive_avg': 295.4,
#     'earnings': 498341.0,
#     'earnings_rank': 157,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 68.17,
#     'hole_proximity_avg': '37\' 4"',
#     'holes_per_eagle': 283.5,
#     'points': 0,
#     'points_rank': 149,
#     'putt_avg': 1.777,
#     'sand_saves_pct': 46.15,
#     'scoring_avg': 70.861,
#     'scrambling_pct': 59.83,
#     'second_place': 0,
#     'strokes_gained': 0.449,
#     'strokes_gained_tee_green': -0.355,
#     'strokes_gained_total': 0.094,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 4,
#     'total_driving': 169,
#     'withdrawals': 0,
#     'world_rank': 168}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Kyle',
#    'id': 'a7d48a3d-b5fd-41bf-bd42-f9ce8fbdbcd2',
#    'last_name': 'Thompson',
#    'statistics': {'birdies_per_round': 3.26,
#     'cuts': 20,
#     'cuts_made': 2,
#     'drive_acc': 62.99,
#     'drive_avg': 285.3,
#     'earnings': 24878.0,
#     'earnings_rank': 235,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 62.44,
#     'hole_proximity_avg': '34\' 10"',
#     'points': 0,
#     'points_rank': 236,
#     'putt_avg': 1.797,
#     'sand_saves_pct': 51.28,
#     'scoring_avg': 72.673,
#     'scrambling_pct': 54.02,
#     'second_place': 0,
#     'strokes_gained': -0.75,
#     'strokes_gained_tee_green': -0.512,
#     'strokes_gained_total': -1.262,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'total_driving': 257,
#     'withdrawals': 0,
#     'world_rank': 687}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Luke',
#    'id': '59e38135-5887-43e5-b6ab-25cbfedcd6e5',
#    'last_name': 'List',
#    'statistics': {'birdies_per_round': 3.86,
#     'cuts': 9,
#     'cuts_made': 20,
#     'drive_acc': 54.69,
#     'drive_avg': 314.7,
#     'earnings': 2710736.0,
#     'earnings_rank': 36,
#     'events_played': 29,
#     'first_place': 0,
#     'gir_pct': 68.76,
#     'hole_proximity_avg': '37\' 7"',
#     'holes_per_eagle': 213.8,
#     'points': 0,
#     'points_rank': 45,
#     'putt_avg': 1.791,
#     'sand_saves_pct': 53.14,
#     'scoring_avg': 70.229,
#     'scrambling_pct': 58.89,
#     'second_place': 1,
#     'strokes_gained': -0.445,
#     'strokes_gained_tee_green': 1.364,
#     'strokes_gained_total': 0.919,
#     'third_place': 1,
#     'top_10': 5,
#     'top_25': 11,
#     'total_driving': 183,
#     'withdrawals': 0,
#     'world_rank': 54}},
#   {'country': 'ENGLAND',
#    'first_name': 'Andrew',
#    'id': 'aa7840f5-a78d-422e-a4d7-e7541d1518d4',
#    'last_name': 'Johnston',
#    'statistics': {'birdies_per_round': 1.83,
#     'cuts': 1,
#     'cuts_made': 1,
#     'drive_acc': 60.71,
#     'drive_avg': 295.5,
#     'earnings': 24448.0,
#     'earnings_rank': 236,
#     'events_played': 2,
#     'first_place': 0,
#     'gir_pct': 52.78,
#     'hole_proximity_avg': '49\' 10"',
#     'points': 0,
#     'points_rank': 245,
#     'putt_avg': 1.737,
#     'sand_saves_pct': 33.33,
#     'scoring_avg': 72.601,
#     'scrambling_pct': 23.53,
#     'second_place': 0,
#     'strokes_gained': -1.369,
#     'strokes_gained_tee_green': -5.969,
#     'strokes_gained_total': -7.338,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 0,
#     'world_rank': 178}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Andrew',
#    'id': '733acbdb-d1aa-4b49-a24c-f4f425735ce0',
#    'last_name': 'Landry',
#    'statistics': {'birdies_per_round': 3.5,
#     'cuts': 10,
#     'cuts_made': 15,
#     'drive_acc': 62.92,
#     'drive_avg': 291.1,
#     'earnings': 2642179.0,
#     'earnings_rank': 41,
#     'events_played': 27,
#     'first_place': 1,
#     'gir_pct': 65.63,
#     'hole_proximity_avg': '33\' 9"',
#     'holes_per_eagle': 180.0,
#     'points': 0,
#     'points_rank': 37,
#     'putt_avg': 1.756,
#     'sand_saves_pct': 42.64,
#     'scoring_avg': 71.059,
#     'scrambling_pct': 56.97,
#     'second_place': 1,
#     'strokes_gained': -0.01,
#     'strokes_gained_tee_green': -0.029,
#     'strokes_gained_total': -0.039,
#     'third_place': 0,
#     'top_10': 5,
#     'top_25': 5,
#     'total_driving': 222,
#     'withdrawals': 2,
#     'world_rank': 76}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Peter',
#    'id': '5ccb172d-5bbd-4302-a0ad-43ad9ffff64b',
#    'last_name': 'Malnati',
#    'statistics': {'birdies_per_round': 3.73,
#     'cuts': 13,
#     'cuts_made': 15,
#     'drive_acc': 56.86,
#     'drive_avg': 290.9,
#     'earnings': 420001.0,
#     'earnings_rank': 167,
#     'events_played': 28,
#     'first_place': 0,
#     'gir_pct': 62.99,
#     'hole_proximity_avg': '37\' 6"',
#     'holes_per_eagle': 373.5,
#     'points': 0,
#     'points_rank': 161,
#     'putt_avg': 1.723,
#     'sand_saves_pct': 56.69,
#     'scoring_avg': 70.841,
#     'scrambling_pct': 61.3,
#     'second_place': 0,
#     'strokes_gained': 0.619,
#     'strokes_gained_tee_green': -0.374,
#     'strokes_gained_total': 0.244,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 2,
#     'total_driving': 298,
#     'withdrawals': 0,
#     'world_rank': 330}},
#   {'country': 'CANADA',
#    'first_name': 'Graham',
#    'id': '66f00a14-69d8-4ba8-b322-25318fae56b6',
#    'last_name': 'DeLaet',
#    'statistics': {'birdies_per_round': 4.4,
#     'cuts': 0,
#     'cuts_made': 3,
#     'drive_acc': 57.14,
#     'drive_avg': 315.9,
#     'earnings': 251630.0,
#     'earnings_rank': 187,
#     'events_played': 3,
#     'first_place': 0,
#     'gir_pct': 74.44,
#     'hole_proximity_avg': '29\' 5"',
#     'holes_per_eagle': 180.0,
#     'points': 0,
#     'points_rank': 187,
#     'putt_avg': 1.769,
#     'sand_saves_pct': 33.33,
#     'scoring_avg': 71.857,
#     'scrambling_pct': 41.3,
#     'second_place': 0,
#     'strokes_gained': 0.371,
#     'strokes_gained_tee_green': 2.249,
#     'strokes_gained_total': 2.62,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 1,
#     'withdrawals': 1,
#     'world_rank': 294}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Xander',
#    'id': '26dc0bda-b9a8-4303-9c1c-ddecda3817d2',
#    'last_name': 'Schauffele',
#    'statistics': {'birdies_per_round': 3.81,
#     'cuts': 5,
#     'cuts_made': 22,
#     'drive_acc': 59.09,
#     'drive_avg': 304.6,
#     'earnings': 4047538.0,
#     'earnings_rank': 18,
#     'events_played': 27,
#     'first_place': 0,
#     'gir_pct': 65.79,
#     'hole_proximity_avg': '37\' 2"',
#     'holes_per_eagle': 239.1,
#     'points': 581.0,
#     'points_rank': 15,
#     'putt_avg': 1.764,
#     'sand_saves_pct': 48.91,
#     'scoring_avg': 70.486,
#     'scrambling_pct': 58.76,
#     'second_place': 2,
#     'strokes_gained': 0.125,
#     'strokes_gained_tee_green': 0.386,
#     'strokes_gained_total': 0.511,
#     'third_place': 2,
#     'top_10': 7,
#     'top_25': 12,
#     'total_driving': 155,
#     'withdrawals': 0,
#     'world_rank': 18}},
#   {'country': 'SCOTLAND',
#    'first_name': 'Martin',
#    'id': '45a571da-a1e4-4d48-9f88-47bb5185f0d0',
#    'last_name': 'Laird',
#    'statistics': {'birdies_per_round': 3.89,
#     'cuts': 8,
#     'cuts_made': 14,
#     'drive_acc': 63.22,
#     'drive_avg': 299.0,
#     'earnings': 1017580.0,
#     'earnings_rank': 114,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 65.9,
#     'hole_proximity_avg': '35\' 8"',
#     'holes_per_eagle': 167.1,
#     'points': 0,
#     'points_rank': 115,
#     'putt_avg': 1.764,
#     'sand_saves_pct': 50.48,
#     'scoring_avg': 70.839,
#     'scrambling_pct': 59.15,
#     'second_place': 0,
#     'strokes_gained': 0.282,
#     'strokes_gained_tee_green': 0.189,
#     'strokes_gained_total': 0.47,
#     'third_place': 0,
#     'top_10': 3,
#     'top_25': 7,
#     'total_driving': 144,
#     'withdrawals': 0,
#     'world_rank': 164}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Ryan',
#    'id': 'd247f602-d0a2-4533-bc5a-5a9bda24b29e',
#    'last_name': 'Blaum',
#    'statistics': {'birdies_per_round': 3.78,
#     'cuts': 12,
#     'cuts_made': 14,
#     'drive_acc': 64.31,
#     'drive_avg': 289.0,
#     'earnings': 980877.0,
#     'earnings_rank': 116,
#     'events_played': 28,
#     'first_place': 0,
#     'gir_pct': 66.1,
#     'hole_proximity_avg': '36\' 11"',
#     'holes_per_eagle': 156.0,
#     'points': 0,
#     'points_rank': 121,
#     'putt_avg': 1.761,
#     'sand_saves_pct': 41.54,
#     'scoring_avg': 70.993,
#     'scrambling_pct': 55.46,
#     'second_place': 0,
#     'strokes_gained': 0.025,
#     'strokes_gained_tee_green': -0.058,
#     'strokes_gained_total': -0.033,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 8,
#     'total_driving': 221,
#     'withdrawals': 2,
#     'world_rank': 273}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Shawn',
#    'id': '014b0edb-de5f-4492-8873-60bf3313b54d',
#    'last_name': 'Stefani',
#    'statistics': {'birdies_per_round': 3.64,
#     'cuts': 13,
#     'cuts_made': 12,
#     'drive_acc': 56.52,
#     'drive_avg': 299.6,
#     'earnings': 523204.0,
#     'earnings_rank': 155,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 67.49,
#     'hole_proximity_avg': '34\' 9"',
#     'holes_per_eagle': 190.3,
#     'points': 0,
#     'points_rank': 147,
#     'putt_avg': 1.78,
#     'sand_saves_pct': 47.5,
#     'scoring_avg': 71.192,
#     'scrambling_pct': 58.43,
#     'second_place': 0,
#     'strokes_gained': -0.034,
#     'strokes_gained_tee_green': 0.141,
#     'strokes_gained_total': 0.107,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 6,
#     'total_driving': 219,
#     'withdrawals': 0,
#     'world_rank': 344}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Derek',
#    'id': '34db16d4-d06d-4b81-ba77-509f9d3b70f4',
#    'last_name': 'Fathauer',
#    'statistics': {'birdies_per_round': 3.44,
#     'cuts': 14,
#     'cuts_made': 14,
#     'drive_acc': 53.27,
#     'drive_avg': 289.1,
#     'earnings': 708712.0,
#     'earnings_rank': 135,
#     'events_played': 28,
#     'first_place': 0,
#     'gir_pct': 60.35,
#     'hole_proximity_avg': '38\' 11"',
#     'holes_per_eagle': 160.0,
#     'points': 0,
#     'points_rank': 137,
#     'putt_avg': 1.754,
#     'sand_saves_pct': 43.62,
#     'scoring_avg': 71.827,
#     'scrambling_pct': 54.99,
#     'second_place': 0,
#     'strokes_gained': 0.363,
#     'strokes_gained_tee_green': -1.17,
#     'strokes_gained_total': -0.807,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 6,
#     'total_driving': 349,
#     'withdrawals': 0,
#     'world_rank': 381}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Scott',
#    'id': 'd28839e8-d9f0-483f-9932-227775cb78cf',
#    'last_name': 'Stallings',
#    'statistics': {'birdies_per_round': 3.5,
#     'cuts': 12,
#     'cuts_made': 18,
#     'drive_acc': 55.99,
#     'drive_avg': 299.7,
#     'earnings': 1147573.0,
#     'earnings_rank': 105,
#     'events_played': 30,
#     'first_place': 0,
#     'gir_pct': 65.91,
#     'hole_proximity_avg': '36\' 5"',
#     'holes_per_eagle': 231.4,
#     'points': 0,
#     'points_rank': 93,
#     'putt_avg': 1.787,
#     'sand_saves_pct': 56.69,
#     'scoring_avg': 70.719,
#     'scrambling_pct': 61.85,
#     'second_place': 0,
#     'strokes_gained': -0.012,
#     'strokes_gained_tee_green': 0.34,
#     'strokes_gained_total': 0.328,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 5,
#     'total_driving': 224,
#     'withdrawals': 0,
#     'world_rank': 160}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Bronson',
#    'id': 'ed67db92-af39-4ea1-9b67-47d94b63bc19',
#    'last_name': 'Burgoon',
#    'statistics': {'birdies_per_round': 3.81,
#     'cuts': 12,
#     'cuts_made': 11,
#     'drive_acc': 64.53,
#     'drive_avg': 302.8,
#     'earnings': 1179616.0,
#     'earnings_rank': 103,
#     'events_played': 24,
#     'first_place': 0,
#     'gir_pct': 68.44,
#     'hole_proximity_avg': '35\' 11"',
#     'holes_per_eagle': 138.0,
#     'points': 0,
#     'points_rank': 78,
#     'putt_avg': 1.778,
#     'sand_saves_pct': 45.95,
#     'scoring_avg': 70.701,
#     'scrambling_pct': 55.61,
#     'second_place': 1,
#     'strokes_gained': 0.107,
#     'strokes_gained_tee_green': 0.373,
#     'strokes_gained_total': 0.481,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 6,
#     'total_driving': 92,
#     'withdrawals': 1,
#     'world_rank': 161}},
#   {'country': 'ENGLAND',
#    'first_name': 'Tommy',
#    'id': '6577ec3d-9e78-4979-8f4c-01c465fa6b1d',
#    'last_name': 'Fleetwood',
#    'statistics': {'birdies_per_round': 4.32,
#     'cuts': 1,
#     'cuts_made': 18,
#     'drive_acc': 63.65,
#     'drive_avg': 306.9,
#     'earnings': 3935147.0,
#     'earnings_rank': 21,
#     'events_played': 19,
#     'first_place': 0,
#     'gir_pct': 69.35,
#     'hole_proximity_avg': '36\' 11"',
#     'holes_per_eagle': 132.0,
#     'points': 483.0,
#     'points_rank': 19,
#     'putt_avg': 1.742,
#     'sand_saves_pct': 52.21,
#     'scoring_avg': 69.342,
#     'scrambling_pct': 56.14,
#     'second_place': 1,
#     'strokes_gained': 0.233,
#     'strokes_gained_tee_green': 1.189,
#     'strokes_gained_total': 1.423,
#     'third_place': 0,
#     'top_10': 6,
#     'top_25': 15,
#     'total_driving': 87,
#     'withdrawals': 0,
#     'world_rank': 12}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Nicholas',
#    'id': '4624803d-082d-4dec-b496-3e462caa9e1c',
#    'last_name': 'Lindheim',
#    'statistics': {'birdies_per_round': 3.68,
#     'cuts': 11,
#     'cuts_made': 13,
#     'drive_acc': 60.44,
#     'drive_avg': 293.5,
#     'earnings': 593842.0,
#     'earnings_rank': 146,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 68.04,
#     'hole_proximity_avg': '36\' 4"',
#     'holes_per_eagle': 1242.0,
#     'points': 0,
#     'points_rank': 146,
#     'putt_avg': 1.762,
#     'sand_saves_pct': 43.96,
#     'scoring_avg': 71.344,
#     'scrambling_pct': 53.9,
#     'second_place': 0,
#     'strokes_gained': 0.355,
#     'strokes_gained_tee_green': -0.678,
#     'strokes_gained_total': -0.323,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 4,
#     'total_driving': 229,
#     'withdrawals': 2,
#     'world_rank': 336}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Peter',
#    'id': '3f82c91a-47f0-4551-8500-04784e940cde',
#    'last_name': 'Uihlein',
#    'statistics': {'birdies_per_round': 3.65,
#     'cuts': 10,
#     'cuts_made': 16,
#     'drive_acc': 52.41,
#     'drive_avg': 302.0,
#     'earnings': 1797715.0,
#     'earnings_rank': 67,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 68.17,
#     'hole_proximity_avg': '37\' 2"',
#     'holes_per_eagle': 156.0,
#     'points': 0,
#     'points_rank': 64,
#     'putt_avg': 1.78,
#     'sand_saves_pct': 56.6,
#     'scoring_avg': 70.578,
#     'scrambling_pct': 59.67,
#     'second_place': 0,
#     'strokes_gained': 0.063,
#     'strokes_gained_tee_green': 0.197,
#     'strokes_gained_total': 0.26,
#     'third_place': 0,
#     'top_10': 4,
#     'top_25': 8,
#     'total_driving': 236,
#     'withdrawals': 0,
#     'world_rank': 65}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Rob',
#    'id': '0f455b60-77bb-45f6-849d-9b4a711cf4ab',
#    'last_name': 'Oppenheim',
#    'statistics': {'birdies_per_round': 3.48,
#     'cuts': 15,
#     'cuts_made': 11,
#     'drive_acc': 56.23,
#     'drive_avg': 284.7,
#     'earnings': 279019.0,
#     'earnings_rank': 185,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 63.89,
#     'hole_proximity_avg': '35\' 11"',
#     'holes_per_eagle': 198.0,
#     'points': 0,
#     'points_rank': 180,
#     'putt_avg': 1.767,
#     'sand_saves_pct': 60.55,
#     'scoring_avg': 71.478,
#     'scrambling_pct': 60.37,
#     'second_place': 0,
#     'strokes_gained': 0.068,
#     'strokes_gained_tee_green': -0.503,
#     'strokes_gained_total': -0.435,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 2,
#     'total_driving': 350,
#     'withdrawals': 0,
#     'world_rank': 345}},
#   {'country': 'MEXICO',
#    'first_name': 'Roberto',
#    'id': '1129f9c2-0ebb-4b1f-9440-3c08cfd654b1',
#    'last_name': 'Diaz',
#    'statistics': {'birdies_per_round': 3.18,
#     'cuts': 12,
#     'cuts_made': 11,
#     'drive_acc': 63.2,
#     'drive_avg': 286.3,
#     'earnings': 235635.0,
#     'earnings_rank': 188,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 63.73,
#     'hole_proximity_avg': '37\' 2"',
#     'holes_per_eagle': 306.0,
#     'points': 0,
#     'points_rank': 189,
#     'putt_avg': 1.794,
#     'sand_saves_pct': 50.0,
#     'scoring_avg': 71.731,
#     'scrambling_pct': 58.56,
#     'second_place': 0,
#     'strokes_gained': 0.168,
#     'strokes_gained_tee_green': -1.001,
#     'strokes_gained_total': -0.833,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'total_driving': 249,
#     'withdrawals': 2,
#     'world_rank': 654}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Steve',
#    'id': '1e4bf43f-dda6-4d88-87c5-d3a229c99a44',
#    'last_name': 'Stricker',
#    'statistics': {'birdies_per_round': 3.75,
#     'cuts': 3,
#     'cuts_made': 9,
#     'drive_acc': 66.73,
#     'drive_avg': 288.7,
#     'earnings': 582566.0,
#     'earnings_rank': 147,
#     'events_played': 12,
#     'first_place': 0,
#     'gir_pct': 69.29,
#     'hole_proximity_avg': '33\' 2"',
#     'holes_per_eagle': 144.0,
#     'points': 0,
#     'points_rank': 145,
#     'putt_avg': 1.744,
#     'sand_saves_pct': 51.72,
#     'scoring_avg': 69.934,
#     'scrambling_pct': 61.81,
#     'second_place': 0,
#     'strokes_gained': -0.064,
#     'strokes_gained_tee_green': 0.89,
#     'strokes_gained_total': 0.825,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 4,
#     'withdrawals': 0,
#     'world_rank': 169}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Dustin',
#    'id': 'a7041051-eb25-40b9-acb3-dab88cae69c0',
#    'last_name': 'Johnson',
#    'statistics': {'birdies_per_round': 4.7,
#     'cuts': 1,
#     'cuts_made': 19,
#     'drive_acc': 58.27,
#     'drive_avg': 314.0,
#     'earnings': 8457352.0,
#     'earnings_rank': 2,
#     'events_played': 20,
#     'first_place': 3,
#     'gir_pct': 70.63,
#     'hole_proximity_avg': '32\' 5"',
#     'holes_per_eagle': 88.8,
#     'points': 2056.0,
#     'points_rank': 4,
#     'putt_avg': 1.689,
#     'sand_saves_pct': 51.16,
#     'scoring_avg': 68.698,
#     'scrambling_pct': 62.97,
#     'second_place': 2,
#     'strokes_gained': 0.359,
#     'strokes_gained_tee_green': 1.924,
#     'strokes_gained_total': 2.284,
#     'third_place': 3,
#     'top_10': 12,
#     'top_25': 17,
#     'total_driving': 144,
#     'withdrawals': 0,
#     'world_rank': 1}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Paul',
#    'id': 'd06bf9ba-4907-4ad4-84f5-23a0b0369b07',
#    'last_name': 'Goydos',
#    'statistics': {'birdies_per_round': 1.75,
#     'cuts': 0,
#     'cuts_made': 1,
#     'drive_acc': 67.86,
#     'drive_avg': 260.1,
#     'earnings': 18067.0,
#     'earnings_rank': 244,
#     'events_played': 1,
#     'first_place': 0,
#     'gir_pct': 61.11,
#     'hole_proximity_avg': '32\' 11"',
#     'holes_per_eagle': 36.0,
#     'points': 0,
#     'points_rank': 251,
#     'putt_avg': 1.818,
#     'sand_saves_pct': 25.0,
#     'scoring_avg': 73.007,
#     'scrambling_pct': 53.57,
#     'second_place': 0,
#     'strokes_gained': 0.162,
#     'strokes_gained_tee_green': -1.169,
#     'strokes_gained_total': -1.007,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 0,
#     'world_rank': 2021}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Cody',
#    'id': '1b4e6937-cc92-4c5e-8f7d-dbb46beb4c86',
#    'last_name': 'Gribble',
#    'statistics': {'birdies_per_round': 3.55,
#     'cuts': 15,
#     'cuts_made': 10,
#     'drive_acc': 55.45,
#     'drive_avg': 301.0,
#     'earnings': 302593.0,
#     'earnings_rank': 181,
#     'events_played': 25,
#     'first_place': 0,
#     'gir_pct': 62.48,
#     'hole_proximity_avg': '39\' 0"',
#     'holes_per_eagle': 390.0,
#     'points': 0,
#     'points_rank': 182,
#     'putt_avg': 1.759,
#     'sand_saves_pct': 48.72,
#     'scoring_avg': 72.112,
#     'scrambling_pct': 53.3,
#     'second_place': 0,
#     'strokes_gained': 0.201,
#     'strokes_gained_tee_green': -1.02,
#     'strokes_gained_total': -0.819,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'total_driving': 219,
#     'withdrawals': 0,
#     'world_rank': 576}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Tommy',
#    'id': '06658afa-5d9d-403e-a4a1-4c7d3229858c',
#    'last_name': 'Gainey',
#    'statistics': {'birdies_per_round': 3.77,
#     'cuts': 8,
#     'cuts_made': 2,
#     'drive_acc': 68.18,
#     'drive_avg': 294.2,
#     'earnings': 39508.0,
#     'earnings_rank': 231,
#     'events_played': 10,
#     'first_place': 0,
#     'gir_pct': 66.67,
#     'hole_proximity_avg': '32\' 4"',
#     'holes_per_eagle': 132.0,
#     'points': 0,
#     'points_rank': 223,
#     'putt_avg': 1.742,
#     'sand_saves_pct': 41.38,
#     'scoring_avg': 71.858,
#     'scrambling_pct': 51.52,
#     'second_place': 0,
#     'strokes_gained': 0.068,
#     'strokes_gained_tee_green': -1.305,
#     'strokes_gained_total': -1.237,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 1674}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Andrew',
#    'id': 'bf8aa94c-d1a9-4de4-a05f-322092033fb0',
#    'last_name': 'Putnam',
#    'statistics': {'birdies_per_round': 3.63,
#     'cuts': 7,
#     'cuts_made': 21,
#     'drive_acc': 60.42,
#     'drive_avg': 293.8,
#     'earnings': 2387382.0,
#     'earnings_rank': 49,
#     'events_played': 28,
#     'first_place': 1,
#     'gir_pct': 70.47,
#     'hole_proximity_avg': '36\' 10"',
#     'holes_per_eagle': 320.4,
#     'points': 0,
#     'points_rank': 33,
#     'putt_avg': 1.783,
#     'sand_saves_pct': 48.8,
#     'scoring_avg': 70.579,
#     'scrambling_pct': 61.52,
#     'second_place': 1,
#     'strokes_gained': 0.052,
#     'strokes_gained_tee_green': 0.42,
#     'strokes_gained_total': 0.472,
#     'third_place': 0,
#     'top_10': 5,
#     'top_25': 9,
#     'total_driving': 228,
#     'withdrawals': 0,
#     'world_rank': 78}},
#   {'country': 'JAPAN',
#    'first_name': 'Hideki',
#    'id': 'd45bcf4a-5803-4b0b-ab6c-6427a76cecf7',
#    'last_name': 'Matsuyama',
#    'statistics': {'birdies_per_round': 3.94,
#     'cuts': 2,
#     'cuts_made': 18,
#     'drive_acc': 61.69,
#     'drive_avg': 302.0,
#     'earnings': 2687477.0,
#     'earnings_rank': 39,
#     'events_played': 21,
#     'first_place': 0,
#     'gir_pct': 69.77,
#     'hole_proximity_avg': '35\' 1"',
#     'holes_per_eagle': 92.6,
#     'points': 602.0,
#     'points_rank': 13,
#     'putt_avg': 1.747,
#     'sand_saves_pct': 53.41,
#     'scoring_avg': 70.022,
#     'scrambling_pct': 61.08,
#     'second_place': 0,
#     'strokes_gained': 0.115,
#     'strokes_gained_tee_green': 1.028,
#     'strokes_gained_total': 1.143,
#     'third_place': 0,
#     'top_10': 4,
#     'top_25': 12,
#     'total_driving': 143,
#     'withdrawals': 1,
#     'world_rank': 21}},
#   {'country': 'CHINA',
#    'first_name': 'Zecheng',
#    'id': '2af25cc3-2251-4408-902b-4a1d88e40fef',
#    'last_name': 'Dou',
#    'statistics': {'birdies_per_round': 3.14,
#     'cuts': 17,
#     'cuts_made': 4,
#     'drive_acc': 54.76,
#     'drive_avg': 291.9,
#     'earnings': 90993.0,
#     'earnings_rank': 214,
#     'events_played': 23,
#     'first_place': 0,
#     'gir_pct': 63.72,
#     'hole_proximity_avg': '37\' 3"',
#     'holes_per_eagle': 294.0,
#     'points': 0,
#     'points_rank': 227,
#     'putt_avg': 1.822,
#     'sand_saves_pct': 46.51,
#     'scoring_avg': 72.773,
#     'scrambling_pct': 51.56,
#     'second_place': 0,
#     'strokes_gained': -0.667,
#     'strokes_gained_tee_green': -0.531,
#     'strokes_gained_total': -1.198,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'total_driving': 311,
#     'withdrawals': 2,
#     'world_rank': 850}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Davis',
#    'id': 'e45f55ab-d896-475f-a74a-0554aa36e21c',
#    'last_name': 'Love III',
#    'statistics': {'birdies_per_round': 3.18,
#     'cuts': 6,
#     'cuts_made': 5,
#     'drive_acc': 64.13,
#     'drive_avg': 286.4,
#     'earnings': 97920.0,
#     'earnings_rank': 209,
#     'events_played': 12,
#     'first_place': 0,
#     'gir_pct': 61.95,
#     'hole_proximity_avg': '32\' 10"',
#     'holes_per_eagle': 297.0,
#     'points': 0,
#     'points_rank': 210,
#     'putt_avg': 1.793,
#     'sand_saves_pct': 42.86,
#     'scoring_avg': 72.385,
#     'scrambling_pct': 57.08,
#     'second_place': 0,
#     'strokes_gained': -0.675,
#     'strokes_gained_tee_green': -0.522,
#     'strokes_gained_total': -1.198,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 1,
#     'world_rank': 1058}},
#   {'country': 'SOUTH AFRICA',
#    'first_name': 'Louis',
#    'id': 'c19bc908-1c6a-4315-b51c-fa5a335bfeec',
#    'last_name': 'Oosthuizen',
#    'statistics': {'birdies_per_round': 3.43,
#     'cuts': 3,
#     'cuts_made': 14,
#     'drive_acc': 63.29,
#     'drive_avg': 299.5,
#     'earnings': 1731493.0,
#     'earnings_rank': 69,
#     'events_played': 17,
#     'first_place': 0,
#     'gir_pct': 66.0,
#     'hole_proximity_avg': '33\' 10"',
#     'holes_per_eagle': 486.0,
#     'points': 0,
#     'points_rank': 69,
#     'putt_avg': 1.798,
#     'sand_saves_pct': 63.73,
#     'scoring_avg': 70.157,
#     'scrambling_pct': 65.03,
#     'second_place': 0,
#     'strokes_gained': -0.032,
#     'strokes_gained_tee_green': 0.423,
#     'strokes_gained_total': 0.39,
#     'third_place': 1,
#     'top_10': 3,
#     'top_25': 9,
#     'total_driving': 137,
#     'withdrawals': 0,
#     'world_rank': 36}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Pat',
#    'id': '827eafe9-e092-4020-bc94-634b031900ed',
#    'last_name': 'Perez',
#    'statistics': {'birdies_per_round': 3.85,
#     'cuts': 4,
#     'cuts_made': 19,
#     'drive_acc': 64.54,
#     'drive_avg': 291.9,
#     'earnings': 2962641.0,
#     'earnings_rank': 31,
#     'events_played': 23,
#     'first_place': 1,
#     'gir_pct': 68.39,
#     'hole_proximity_avg': '35\' 6"',
#     'holes_per_eagle': 675.0,
#     'points': 0,
#     'points_rank': 39,
#     'putt_avg': 1.76,
#     'sand_saves_pct': 44.74,
#     'scoring_avg': 70.594,
#     'scrambling_pct': 56.19,
#     'second_place': 1,
#     'strokes_gained': 0.087,
#     'strokes_gained_tee_green': -0.237,
#     'strokes_gained_total': -0.15,
#     'third_place': 0,
#     'top_10': 4,
#     'top_25': 7,
#     'total_driving': 185,
#     'withdrawals': 1,
#     'world_rank': 53}},
#   {'country': 'GERMANY',
#    'first_name': 'Stephan',
#    'id': '5488bb49-3607-4517-a3a1-5cf68737aa37',
#    'last_name': 'Jaeger',
#    'statistics': {'birdies_per_round': 3.44,
#     'cuts': 12,
#     'cuts_made': 14,
#     'drive_acc': 58.76,
#     'drive_avg': 299.2,
#     'earnings': 422260.0,
#     'earnings_rank': 165,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 67.11,
#     'hole_proximity_avg': '37\' 3"',
#     'holes_per_eagle': 270.0,
#     'points': 0,
#     'points_rank': 165,
#     'putt_avg': 1.79,
#     'sand_saves_pct': 46.97,
#     'scoring_avg': 71.356,
#     'scrambling_pct': 56.76,
#     'second_place': 0,
#     'strokes_gained': -0.144,
#     'strokes_gained_tee_green': 0.054,
#     'strokes_gained_total': -0.09,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 3,
#     'total_driving': 200,
#     'withdrawals': 0,
#     'world_rank': 224}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Ted',
#    'id': '03bdd912-c363-4517-99b5-7a1ec757ebe5',
#    'last_name': 'Potter Jr.',
#    'statistics': {'birdies_per_round': 3.57,
#     'cuts': 13,
#     'cuts_made': 15,
#     'drive_acc': 66.72,
#     'drive_avg': 285.6,
#     'earnings': 1976198.0,
#     'earnings_rank': 58,
#     'events_played': 28,
#     'first_place': 1,
#     'gir_pct': 63.33,
#     'hole_proximity_avg': '35\' 1"',
#     'holes_per_eagle': 223.7,
#     'points': 0,
#     'points_rank': 65,
#     'putt_avg': 1.757,
#     'sand_saves_pct': 52.35,
#     'scoring_avg': 71.024,
#     'scrambling_pct': 58.82,
#     'second_place': 0,
#     'strokes_gained': 0.082,
#     'strokes_gained_tee_green': -0.126,
#     'strokes_gained_total': -0.045,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 4,
#     'total_driving': 202,
#     'withdrawals': 0,
#     'world_rank': 98}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Michael',
#    'id': '6ad1215a-824f-43e4-9bbe-169a5df02cc2',
#    'last_name': 'Thompson',
#    'statistics': {'birdies_per_round': 3.72,
#     'cuts': 7,
#     'cuts_made': 12,
#     'drive_acc': 64.66,
#     'drive_avg': 296.4,
#     'earnings': 563972.0,
#     'earnings_rank': 151,
#     'events_played': 19,
#     'first_place': 0,
#     'gir_pct': 70.11,
#     'hole_proximity_avg': '36\' 3"',
#     'holes_per_eagle': 1044.0,
#     'points': 0,
#     'points_rank': 142,
#     'putt_avg': 1.776,
#     'sand_saves_pct': 48.61,
#     'scoring_avg': 70.924,
#     'scrambling_pct': 55.77,
#     'second_place': 0,
#     'strokes_gained': 0.498,
#     'strokes_gained_tee_green': -0.446,
#     'strokes_gained_total': 0.052,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 5,
#     'total_driving': 138,
#     'withdrawals': 0,
#     'world_rank': 302}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Grayson',
#    'id': '7edd8344-4f0b-4ea0-beb2-cdb5c093890f',
#    'last_name': 'Murray',
#    'statistics': {'birdies_per_round': 3.96,
#     'cuts': 5,
#     'cuts_made': 15,
#     'drive_acc': 56.0,
#     'drive_avg': 307.3,
#     'earnings': 1056628.0,
#     'earnings_rank': 112,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 62.5,
#     'hole_proximity_avg': '37\' 1"',
#     'holes_per_eagle': 162.0,
# ...
#     'second_place': 1,
#     'strokes_gained': 0.232,
#     'strokes_gained_tee_green': 0.501,
#     'strokes_gained_total': 0.733,
#     'third_place': 0,
#     'top_10': 4,
#     'top_25': 10,
#     'total_driving': 110,
#     'withdrawals': 0,
#     'world_rank': 50}},
#   {'country': 'UNITED STATES',
#    'first_name': 'John',
#    'id': '0d50e06b-f619-4c7f-b241-7aae49d34aaa',
#    'last_name': 'Rollins',
#    'statistics': {'birdies_per_round': 2.56,
#     'cuts': 7,
#     'cuts_made': 2,
#     'drive_acc': 60.32,
#     'drive_avg': 284.2,
#     'earnings': 15598.0,
#     'earnings_rank': 245,
#     'events_played': 9,
#     'first_place': 0,
#     'gir_pct': 65.43,
#     'hole_proximity_avg': '36\' 3"',
#     'holes_per_eagle': 324.0,
#     'points': 0,
#     'points_rank': 247,
#     'putt_avg': 1.849,
#     'sand_saves_pct': 26.32,
#     'scoring_avg': 73.551,
#     'scrambling_pct': 52.68,
#     'second_place': 0,
#     'strokes_gained': -0.843,
#     'strokes_gained_tee_green': -1.253,
#     'strokes_gained_total': -2.096,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 0,
#     'world_rank': 2021}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Andrew',
#    'id': 'd79fb61f-1ce8-4392-b158-a8ac848aa373',
#    'last_name': 'Yun',
#    'statistics': {'birdies_per_round': 3.13,
#     'cuts': 19,
#     'cuts_made': 3,
#     'drive_acc': 53.58,
#     'drive_avg': 290.6,
#     'earnings': 41566.0,
#     'earnings_rank': 230,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 61.85,
#     'hole_proximity_avg': '37\' 8"',
#     'holes_per_eagle': 810.0,
#     'points': 0,
#     'points_rank': 231,
#     'putt_avg': 1.808,
#     'sand_saves_pct': 34.33,
#     'scoring_avg': 73.624,
#     'scrambling_pct': 44.01,
#     'second_place': 0,
#     'strokes_gained': -0.6,
#     'strokes_gained_tee_green': -1.336,
#     'strokes_gained_total': -1.936,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'total_driving': 350,
#     'withdrawals': 0,
#     'world_rank': 708}},
#   {'country': 'SWEDEN',
#    'first_name': 'Daniel',
#    'id': '14c0985a-169b-480a-8933-0d83b0a9025f',
#    'last_name': 'Chopra',
#    'statistics': {'birdies_per_round': 3.33,
#     'cuts': 5,
#     'cuts_made': 1,
#     'drive_acc': 61.9,
#     'drive_avg': 291.7,
#     'earnings': 8784.0,
#     'earnings_rank': 252,
#     'events_played': 6,
#     'first_place': 0,
#     'gir_pct': 59.26,
#     'hole_proximity_avg': '39\' 11"',
#     'holes_per_eagle': 216.0,
#     'points': 0,
#     'points_rank': 241,
#     'putt_avg': 1.773,
#     'sand_saves_pct': 53.85,
#     'scoring_avg': 72.498,
#     'scrambling_pct': 62.5,
#     'second_place': 0,
#     'strokes_gained': 0.256,
#     'strokes_gained_tee_green': -2.281,
#     'strokes_gained_total': -2.025,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 0,
#     'world_rank': 1236}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Lucas',
#    'id': '88c2edb1-7551-4920-91ad-71c971e51e8c',
#    'last_name': 'Glover',
#    'statistics': {'birdies_per_round': 3.48,
#     'cuts': 3,
#     'cuts_made': 15,
#     'drive_acc': 64.6,
#     'drive_avg': 297.2,
#     'earnings': 789382.0,
#     'earnings_rank': 131,
#     'events_played': 18,
#     'first_place': 0,
#     'gir_pct': 67.61,
#     'hole_proximity_avg': '37\' 9"',
#     'holes_per_eagle': 219.6,
#     'points': 0,
#     'points_rank': 135,
#     'putt_avg': 1.806,
#     'sand_saves_pct': 51.24,
#     'scoring_avg': 71.066,
#     'scrambling_pct': 60.76,
#     'second_place': 0,
#     'strokes_gained': -0.149,
#     'strokes_gained_tee_green': 0.413,
#     'strokes_gained_total': 0.264,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 4,
#     'total_driving': 135,
#     'withdrawals': 0,
#     'world_rank': 136}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Lanto',
#    'id': '0cfa22b7-e601-49f6-b85b-3dfd54cf652e',
#    'last_name': 'Griffin',
#    'statistics': {'birdies_per_round': 3.77,
#     'cuts': 13,
#     'cuts_made': 13,
#     'drive_acc': 54.52,
#     'drive_avg': 302.4,
#     'earnings': 358380.0,
#     'earnings_rank': 176,
#     'events_played': 26,
#     'first_place': 0,
#     'gir_pct': 67.82,
#     'hole_proximity_avg': '35\' 9"',
#     'holes_per_eagle': 166.5,
#     'points': 0,
#     'points_rank': 171,
#     'putt_avg': 1.77,
#     'sand_saves_pct': 50.91,
#     'scoring_avg': 71.145,
#     'scrambling_pct': 56.35,
#     'second_place': 0,
#     'strokes_gained': -0.134,
#     'strokes_gained_tee_green': -0.162,
#     'strokes_gained_total': -0.296,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'total_driving': 227,
#     'withdrawals': 0,
#     'world_rank': 328}},
#   {'country': 'JAPAN',
#    'first_name': 'Satoshi',
#    'id': 'a6e8282b-2a5d-44fb-b28a-4e5c27770aaf',
#    'last_name': 'Kodaira',
#    'statistics': {'birdies_per_round': 2.98,
#     'cuts': 10,
#     'cuts_made': 8,
#     'drive_acc': 64.97,
#     'drive_avg': 293.2,
#     'earnings': 1471462.0,
#     'earnings_rank': 84,
#     'events_played': 18,
#     'first_place': 1,
#     'gir_pct': 60.63,
#     'hole_proximity_avg': '34\' 7"',
#     'holes_per_eagle': 144.0,
#     'points': 0,
#     'points_rank': 94,
#     'putt_avg': 1.819,
#     'sand_saves_pct': 40.24,
#     'scoring_avg': 72.182,
#     'scrambling_pct': 52.76,
#     'second_place': 0,
#     'strokes_gained': -0.536,
#     'strokes_gained_tee_green': -1.183,
#     'strokes_gained_total': -1.72,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 2,
#     'total_driving': 161,
#     'withdrawals': 0,
#     'world_rank': 48}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Matt',
#    'id': '6843212f-76ff-4f93-805e-d5b225f59365',
#    'last_name': 'Every',
#    'statistics': {'birdies_per_round': 3.47,
#     'cuts': 18,
#     'cuts_made': 10,
#     'drive_acc': 55.5,
#     'drive_avg': 294.2,
#     'earnings': 299162.0,
#     'earnings_rank': 182,
#     'events_played': 30,
#     'first_place': 0,
#     'gir_pct': 64.59,
#     'hole_proximity_avg': '37\' 4"',
#     'holes_per_eagle': 112.5,
#     'points': 0,
#     'points_rank': 186,
#     'putt_avg': 1.78,
#     'sand_saves_pct': 48.84,
#     'scoring_avg': 72.044,
#     'scrambling_pct': 52.51,
#     'second_place': 0,
#     'strokes_gained': -0.364,
#     'strokes_gained_tee_green': -0.775,
#     'strokes_gained_total': -1.139,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 1,
#     'total_driving': 278,
#     'withdrawals': 1,
#     'world_rank': 631}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Ricky',
#    'id': '6cafff84-4b93-46ae-acb6-6d74023827e9',
#    'last_name': 'Barnes',
#    'statistics': {'birdies_per_round': 4.07,
#     'cuts': 10,
#     'cuts_made': 11,
#     'drive_acc': 47.15,
#     'drive_avg': 290.6,
#     'earnings': 340591.0,
#     'earnings_rank': 177,
#     'events_played': 22,
#     'first_place': 0,
#     'gir_pct': 63.75,
#     'hole_proximity_avg': '37\' 1"',
#     'holes_per_eagle': 212.4,
#     'points': 0,
#     'points_rank': 175,
#     'putt_avg': 1.708,
#     'sand_saves_pct': 51.65,
#     'scoring_avg': 71.663,
#     'scrambling_pct': 57.4,
#     'second_place': 0,
#     'strokes_gained': 0.338,
#     'strokes_gained_tee_green': -0.703,
#     'strokes_gained_total': -0.365,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 3,
#     'total_driving': 341,
#     'withdrawals': 0,
#     'world_rank': 564}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Brandon',
#    'id': '3faf4d41-ee03-4dbc-9108-d2ca2dad1ba0',
#    'last_name': 'Hagy',
#    'statistics': {'birdies_per_round': 4.2,
#     'cuts': 1,
#     'cuts_made': 2,
#     'drive_acc': 50.71,
#     'drive_avg': 313.4,
#     'earnings': 76817.0,
#     'earnings_rank': 219,
#     'events_played': 3,
#     'first_place': 0,
#     'gir_pct': 63.33,
#     'hole_proximity_avg': '45\' 2"',
#     'points': 0,
#     'points_rank': 215,
#     'putt_avg': 1.737,
#     'sand_saves_pct': 42.86,
#     'scoring_avg': 71.161,
#     'scrambling_pct': 53.03,
#     'second_place': 0,
#     'strokes_gained': 0.631,
#     'strokes_gained_tee_green': 0.436,
#     'strokes_gained_total': 1.066,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 355}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Chris',
#    'id': '7b23951f-d339-4231-a2b2-22b94600224e',
#    'last_name': 'Couch',
#    'statistics': {'birdies_per_round': 2.1,
#     'cuts': 2,
#     'cuts_made': 1,
#     'drive_acc': 58.82,
#     'drive_avg': 281.1,
#     'earnings': 13000.0,
#     'earnings_rank': 248,
#     'events_played': 5,
#     'first_place': 0,
#     'gir_pct': 58.33,
#     'hole_proximity_avg': '37\' 2"',
#     'points': 0,
#     'points_rank': 252,
#     'putt_avg': 1.867,
#     'sand_saves_pct': 56.25,
#     'scoring_avg': 73.861,
#     'scrambling_pct': 52.0,
#     'second_place': 0,
#     'strokes_gained': -0.881,
#     'strokes_gained_tee_green': -2.08,
#     'strokes_gained_total': -2.961,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 2,
#     'world_rank': 2021}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Ben',
#    'id': '59d30dae-b011-4a24-a7c1-285c4e4caf46',
#    'last_name': 'Martin',
#    'statistics': {'birdies_per_round': 3.59,
#     'cuts': 8,
#     'cuts_made': 12,
#     'drive_acc': 63.52,
#     'drive_avg': 289.6,
#     'earnings': 532936.0,
#     'earnings_rank': 154,
#     'events_played': 20,
#     'first_place': 0,
#     'gir_pct': 63.98,
#     'hole_proximity_avg': '38\' 1"',
#     'holes_per_eagle': 384.0,
#     'points': 0,
#     'points_rank': 150,
#     'putt_avg': 1.745,
#     'sand_saves_pct': 57.69,
#     'scoring_avg': 70.974,
#     'scrambling_pct': 58.8,
#     'second_place': 0,
#     'strokes_gained': 0.118,
#     'strokes_gained_tee_green': -0.119,
#     'strokes_gained_total': -0.001,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 3,
#     'total_driving': 224,
#     'withdrawals': 0,
#     'world_rank': 324}},
#   {'country': 'CHINESE TAIPEI',
#    'first_name': 'C.T.',
#    'id': '49fb93d3-5dbe-448f-a0cb-d851087f2019',
#    'last_name': 'Pan',
#    'statistics': {'birdies_per_round': 3.79,
#     'cuts': 8,
#     'cuts_made': 22,
#     'drive_acc': 68.98,
#     'drive_avg': 292.7,
#     'earnings': 1881787.0,
#     'earnings_rank': 65,
#     'events_played': 30,
#     'first_place': 0,
#     'gir_pct': 71.2,
#     'hole_proximity_avg': '35\' 5"',
#     'holes_per_eagle': 252.0,
#     'points': 0,
#     'points_rank': 35,
#     'putt_avg': 1.77,
#     'sand_saves_pct': 42.07,
#     'scoring_avg': 70.457,
#     'scrambling_pct': 56.89,
#     'second_place': 1,
#     'strokes_gained': -0.067,
#     'strokes_gained_tee_green': 0.544,
#     'strokes_gained_total': 0.478,
#     'third_place': 0,
#     'top_10': 2,
#     'top_25': 10,
#     'total_driving': 138,
#     'withdrawals': 0,
#     'world_rank': 100}},
#   {'country': 'SLOVAKIA',
#    'first_name': 'Rory',
#    'id': '2b2a6adc-ff1d-4bc2-9dbd-70781d6fbe89',
#    'last_name': 'Sabbatini',
#    'statistics': {'birdies_per_round': 3.73,
#     'cuts': 7,
#     'cuts_made': 19,
#     'drive_acc': 62.05,
#     'drive_avg': 292.3,
#     'earnings': 1126057.0,
#     'earnings_rank': 107,
#     'events_played': 27,
#     'first_place': 0,
#     'gir_pct': 67.85,
#     'hole_proximity_avg': '36\' 0"',
#     'holes_per_eagle': 133.5,
#     'points': 0,
#     'points_rank': 109,
#     'putt_avg': 1.776,
#     'sand_saves_pct': 60.67,
#     'scoring_avg': 70.693,
#     'scrambling_pct': 61.36,
#     'second_place': 0,
#     'strokes_gained': 0.059,
#     'strokes_gained_tee_green': 0.299,
#     'strokes_gained_total': 0.358,
#     'third_place': 0,
#     'top_10': 1,
#     'top_25': 7,
#     'total_driving': 220,
#     'withdrawals': 1,
#     'world_rank': 163}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Kevin',
#    'id': '4f8a4f4d-8359-4187-b506-3da3ad5b05fb',
#    'last_name': 'Streelman',
#    'statistics': {'birdies_per_round': 3.57,
#     'cuts': 7,
#     'cuts_made': 20,
#     'drive_acc': 69.11,
#     'drive_avg': 295.1,
#     'earnings': 1523642.0,
#     'earnings_rank': 78,
#     'events_played': 27,
#     'first_place': 0,
#     'gir_pct': 71.56,
#     'hole_proximity_avg': '34\' 9"',
#     'holes_per_eagle': 414.0,
#     'points': 0,
#     'points_rank': 77,
#     'putt_avg': 1.797,
#     'sand_saves_pct': 47.24,
#     'scoring_avg': 70.436,
#     'scrambling_pct': 60.93,
#     'second_place': 0,
#     'strokes_gained': -0.25,
#     'strokes_gained_tee_green': 0.868,
#     'strokes_gained_total': 0.619,
#     'third_place': 0,
#     'top_10': 5,
#     'top_25': 8,
#     'total_driving': 118,
#     'withdrawals': 0,
#     'world_rank': 149}},
#   {'country': 'UNITED STATES',
#    'first_name': 'J.B.',
#    'id': '1ec2172c-ed08-493c-b2bc-0df2511b2a8a',
#    'last_name': 'Holmes',
#    'statistics': {'birdies_per_round': 3.59,
#     'cuts': 10,
#     'cuts_made': 14,
#     'drive_acc': 57.13,
#     'drive_avg': 306.1,
#     'earnings': 1595942.0,
#     'earnings_rank': 76,
#     'events_played': 24,
#     'first_place': 0,
#     'gir_pct': 65.26,
#     'hole_proximity_avg': '36\' 0"',
#     'holes_per_eagle': 122.7,
#     'points': 0,
#     'points_rank': 82,
#     'putt_avg': 1.765,
#     'sand_saves_pct': 54.55,
#     'scoring_avg': 70.789,
#     'scrambling_pct': 57.14,
#     'second_place': 1,
#     'strokes_gained': -0.207,
#     'strokes_gained_tee_green': 0.756,
#     'strokes_gained_total': 0.549,
#     'third_place': 1,
#     'top_10': 3,
#     'top_25': 4,
#     'total_driving': 173,
#     'withdrawals': 0,
#     'world_rank': 88}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Troy',
#    'id': '1b7b2620-e9e1-4d6b-aa26-2968a5ad8713',
#    'last_name': 'Matteson',
#    'statistics': {'birdies_per_round': 3.06,
#     'cuts': 6,
#     'cuts_made': 1,
#     'drive_acc': 61.61,
#     'drive_avg': 300.3,
#     'earnings': 39000.0,
#     'earnings_rank': 232,
#     'events_played': 7,
#     'first_place': 0,
#     'gir_pct': 60.76,
#     'hole_proximity_avg': '40\' 6"',
#     'points': 0,
#     'points_rank': 221,
#     'putt_avg': 1.846,
#     'sand_saves_pct': 50.0,
#     'scoring_avg': 73.53,
#     'scrambling_pct': 48.67,
#     'second_place': 0,
#     'strokes_gained': -1.245,
#     'strokes_gained_tee_green': -2.396,
#     'strokes_gained_total': -3.642,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 1526}},
#   {'country': 'GERMANY',
#    'first_name': 'Bernhard',
#    'id': 'ad04909f-3738-4a1b-b931-6d91bace0710',
#    'last_name': 'Langer',
#    'statistics': {'birdies_per_round': 2.25,
#     'cuts': 0,
#     'cuts_made': 2,
#     'drive_acc': 76.72,
#     'drive_avg': 267.8,
#     'earnings': 130200.0,
#     'earnings_rank': 203,
#     'events_played': 2,
#     'first_place': 0,
#     'gir_pct': 68.06,
#     'holes_per_eagle': 144.0,
#     'points': 0,
#     'points_rank': 204,
#     'putt_avg': 1.908,
#     'sand_saves_pct': 50.0,
#     'scoring_avg': 70.81,
#     'scrambling_pct': 65.22,
#     'second_place': 0,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 1,
#     'withdrawals': 0,
#     'world_rank': 751}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Fred',
#    'id': '98e7362d-2df7-4d1d-8e49-a3de535203f3',
#    'last_name': 'Couples',
#    'statistics': {'birdies_per_round': 2.0,
#     'cuts': 0,
#     'cuts_made': 1,
#     'drive_acc': 71.43,
#     'drive_avg': 273.9,
#     'earnings': 46200.0,
#     'earnings_rank': 225,
#     'events_played': 1,
#     'first_place': 0,
#     'gir_pct': 62.5,
#     'points': 0,
#     'points_rank': 230,
#     'putt_avg': 1.867,
#     'sand_saves_pct': 71.43,
#     'scoring_avg': 72.222,
#     'scrambling_pct': 66.67,
#     'second_place': 0,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 0,
#     'world_rank': 978}},
#   {'country': 'UNITED STATES',
#    'first_name': 'Shaun',
#    'id': 'e780af15-95ee-4231-9120-f442e8a5ca64',
#    'last_name': 'Micheel',
#    'statistics': {'birdies_per_round': 2.6,
#     'cuts': 3,
#     'cuts_made': 1,
#     'drive_acc': 68.57,
#     'drive_avg': 279.8,
#     'earnings': 6930.0,
#     'earnings_rank': 257,
#     'events_played': 4,
#     'first_place': 0,
#     'gir_pct': 63.33,
#     'hole_proximity_avg': '35\' 0"',
#     'points': 0,
#     'points_rank': 257,
#     'putt_avg': 1.868,
#     'sand_saves_pct': 41.67,
#     'scoring_avg': 73.294,
#     'scrambling_pct': 62.12,
#     'second_place': 0,
#     'strokes_gained': -0.643,
#     'strokes_gained_tee_green': -1.178,
#     'strokes_gained_total': -1.821,
#     'third_place': 0,
#     'top_10': 0,
#     'top_25': 0,
#     'withdrawals': 0,
#     'world_rank': 2021}}],
#  'season': {'id': 'dbc9bbb1-e51c-47bc-8f72-be7598ffbf7e', 'year': 2018},
#  'tour': {'alias': 'pga',
#   'currency': 'USD',
#   'id': 'b52068af-28e4-4e91-bdbb-037591b0ff84',
#   'name': 'PGA Tour'}}

# %%
result = json_normalize(api, ['players'])
result
# Out:
#               country first_name                                    id  \
# 0       UNITED STATES       D.A.  f5b4cf34-e047-436d-8475-3a62f3bc06ac
# 1       UNITED STATES     Harold  19564b63-f9c8-4263-a689-3135b7755631
# 2       UNITED STATES        Sam  229faa9c-fc01-46bb-a8cb-f6b0310a8cef
# 3       UNITED STATES       Tony  f33d746b-8e14-4325-a4e1-81d6f983b163
# 4       UNITED STATES      Scott  72b41f76-a9a1-4ff9-8364-b8a21129bd54
# 5    NORTHERN IRELAND       Rory  da226913-b804-48de-adbf-96e956eb75ac
# 6       UNITED STATES      Ethan  69630ce8-f1f1-4ce4-a2ed-bec526164e5c
# 7    NORTHERN IRELAND     Graeme  a5ac26e5-464f-457f-a24c-f414cf7a2da3
# 8       UNITED STATES       Bill  a9eb0570-9edd-4de7-8886-f95430d47550
# 9           AUSTRALIA     Stuart  5e8f5e5f-d761-4e22-b1de-2d1b1af6ce8a
# 10      UNITED STATES     Harris  7e11058b-ce7b-4efa-8963-2e48c683ff5b
# 11      UNITED STATES      Brian  92544280-0438-4f43-a5f3-f3a21ea55157
# 12      UNITED STATES      Richy  325e7b91-03b8-4013-bd77-f476303e7d94
# 13        SOUTH KOREA       Whee  fbd310a5-61d2-48e2-9a75-8f57fc3c14f1
# 14          AUSTRALIA      Geoff  d011a6b4-f8c8-4c45-9578-18673407b257
# 15      UNITED STATES     Smylie  1405a98f-75ba-44da-8af9-f9f9db50768f
# 16      UNITED STATES      Steve  14e4ad95-a9f7-4db9-98a3-070aac024b8d
# 17      UNITED STATES      Jamie  6fc571b9-d66d-424a-bcde-71ab62e4a35e
# 18      UNITED STATES   Jonathan  3754ec25-9f1b-427f-9c66-22d399d70c0a
# 19      UNITED STATES    Brendan  5003f675-818b-410a-9f2e-1a860d152900
# 20      UNITED STATES     Bryson  0096b26b-fc25-4fcf-90b9-4b796e3f6c5a
# 21      UNITED STATES      Heath  3621f509-c376-4af1-b1b6-af96c3051463
# 22            IRELAND     Seamus  7da9d857-1f6b-4d76-9396-592d5d9d65eb
# 23      UNITED STATES      Denny  6787bd96-6bf0-4297-b819-85025f81a3a9
# 24      UNITED STATES       Kyle  a7d48a3d-b5fd-41bf-bd42-f9ce8fbdbcd2
# 25      UNITED STATES       Luke  59e38135-5887-43e5-b6ab-25cbfedcd6e5
# 26            ENGLAND     Andrew  aa7840f5-a78d-422e-a4d7-e7541d1518d4
# 27      UNITED STATES     Andrew  733acbdb-d1aa-4b49-a24c-f4f425735ce0
# 28      UNITED STATES      Peter  5ccb172d-5bbd-4302-a0ad-43ad9ffff64b
# 29             CANADA     Graham  66f00a14-69d8-4ba8-b322-25318fae56b6
# ..                ...        ...                                   ...
# 229             ITALY  Francesco  37f07f5b-f185-42d1-ad9a-f665df493554
# 230       NEW ZEALAND      Danny  a4978416-8ed7-4884-ac5f-2bc941b0801d
# 231     UNITED STATES     Parker  65fccbcb-8066-4c32-b9e9-888cf73f1a7c
# 232       SOUTH KOREA     Si Woo  21886b8c-d915-4bbc-9bda-0352821c432b
# 233     UNITED STATES      Jimmy  2db60f6e-7b0a-4daf-97d9-01a057f44f1d
# 234     UNITED STATES        Jim  8e3be4ed-67bf-4c2e-9c96-9581b3c882ba
# 235     UNITED STATES      Brian  0e2ca5ac-0039-4a9e-acac-bec0149f1ef5
# 236     UNITED STATES    Patrick  d072ae36-88f2-4276-b97e-6de87aa2b875
# 237       SOUTH KOREA       K.J.  e6983206-aaf0-4117-a5b8-2d7770044182
# 238     UNITED STATES       Troy  5b5a340c-7b78-4a03-a12c-8f61a0978019
# 239     UNITED STATES      Aaron  e7105de0-27dd-44be-9e39-73ff4df0caa1
# 240     UNITED STATES       John  0d50e06b-f619-4c7f-b241-7aae49d34aaa
# 241     UNITED STATES     Andrew  d79fb61f-1ce8-4392-b158-a8ac848aa373
# 242            SWEDEN     Daniel  14c0985a-169b-480a-8933-0d83b0a9025f
# 243     UNITED STATES      Lucas  88c2edb1-7551-4920-91ad-71c971e51e8c
# 244     UNITED STATES      Lanto  0cfa22b7-e601-49f6-b85b-3dfd54cf652e
# 245             JAPAN    Satoshi  a6e8282b-2a5d-44fb-b28a-4e5c27770aaf
# 246     UNITED STATES       Matt  6843212f-76ff-4f93-805e-d5b225f59365
# 247     UNITED STATES      Ricky  6cafff84-4b93-46ae-acb6-6d74023827e9
# 248     UNITED STATES    Brandon  3faf4d41-ee03-4dbc-9108-d2ca2dad1ba0
# 249     UNITED STATES      Chris  7b23951f-d339-4231-a2b2-22b94600224e
# 250     UNITED STATES        Ben  59d30dae-b011-4a24-a7c1-285c4e4caf46
# 251    CHINESE TAIPEI       C.T.  49fb93d3-5dbe-448f-a0cb-d851087f2019
# 252          SLOVAKIA       Rory  2b2a6adc-ff1d-4bc2-9dbd-70781d6fbe89
# 253     UNITED STATES      Kevin  4f8a4f4d-8359-4187-b506-3da3ad5b05fb
# 254     UNITED STATES       J.B.  1ec2172c-ed08-493c-b2bc-0df2511b2a8a
# 255     UNITED STATES       Troy  1b7b2620-e9e1-4d6b-aa26-2968a5ad8713
# 256           GERMANY   Bernhard  ad04909f-3738-4a1b-b931-6d91bace0710
# 257     UNITED STATES       Fred  98e7362d-2df7-4d1d-8e49-a3de535203f3
# 258     UNITED STATES      Shaun  e780af15-95ee-4231-9120-f442e8a5ca64
#
#       last_name                                         statistics
# 0        Points  {'events_played': 25, 'first_place': 0, 'secon...
# 1    Varner III  {'events_played': 27, 'first_place': 0, 'secon...
# 2         Ryder  {'events_played': 26, 'first_place': 0, 'secon...
# 3         Finau  {'events_played': 28, 'first_place': 0, 'secon...
# 4        Piercy  {'events_played': 26, 'first_place': 1, 'secon...
# 5       McIlroy  {'events_played': 18, 'first_place': 1, 'secon...
# 6         Tracy  {'events_played': 23, 'first_place': 0, 'secon...
# 7      McDowell  {'events_played': 20, 'first_place': 0, 'secon...
# 8          Haas  {'events_played': 25, 'first_place': 0, 'secon...
# 9       Appleby  {'events_played': 12, 'first_place': 0, 'secon...
# 10      English  {'events_played': 31, 'first_place': 0, 'secon...
# 11       Harman  {'events_played': 25, 'first_place': 0, 'secon...
# 12     Werenski  {'events_played': 32, 'first_place': 0, 'secon...
# 13          Kim  {'events_played': 30, 'first_place': 0, 'secon...
# 14       Ogilvy  {'events_played': 18, 'first_place': 0, 'secon...
# 15      Kaufman  {'events_played': 22, 'first_place': 0, 'secon...
# 16       Marino  {'events_played': 6, 'first_place': 0, 'second...
# 17     Lovemark  {'events_played': 26, 'first_place': 0, 'secon...
# 18     Randolph  {'events_played': 25, 'first_place': 0, 'secon...
# 19       Steele  {'events_played': 22, 'first_place': 1, 'secon...
# 20   DeChambeau  {'events_played': 26, 'first_place': 3, 'secon...
# 21       Slocum  {'events_played': 5, 'first_place': 0, 'second...
# 22        Power  {'events_played': 28, 'first_place': 0, 'secon...
# 23     McCarthy  {'events_played': 22, 'first_place': 0, 'secon...
# 24     Thompson  {'events_played': 22, 'first_place': 0, 'secon...
# 25         List  {'events_played': 29, 'first_place': 0, 'secon...
# 26     Johnston  {'events_played': 2, 'first_place': 0, 'second...
# 27       Landry  {'events_played': 27, 'first_place': 1, 'secon...
# 28      Malnati  {'events_played': 28, 'first_place': 0, 'secon...
# 29       DeLaet  {'events_played': 3, 'first_place': 0, 'second...
# ..          ...                                                ...
# 229    Molinari  {'events_played': 20, 'first_place': 2, 'secon...
# 230         Lee  {'events_played': 30, 'first_place': 0, 'secon...
# 231   McLachlin  {'events_played': 11, 'first_place': 0, 'secon...
# 232         Kim  {'events_played': 31, 'first_place': 0, 'secon...
# 233      Walker  {'events_played': 23, 'first_place': 0, 'secon...
# 234       Furyk  {'events_played': 15, 'first_place': 0, 'secon...
# 235      Stuard  {'events_played': 32, 'first_place': 0, 'secon...
# 236     Cantlay  {'events_played': 23, 'first_place': 1, 'secon...
# 237        Choi  {'events_played': 14, 'first_place': 0, 'secon...
# 238     Merritt  {'events_played': 27, 'first_place': 1, 'secon...
# 239        Wise  {'events_played': 29, 'first_place': 1, 'secon...
# 240     Rollins  {'events_played': 9, 'first_place': 0, 'second...
# 241         Yun  {'events_played': 22, 'first_place': 0, 'secon...
# 242      Chopra  {'events_played': 6, 'first_place': 0, 'second...
# 243      Glover  {'events_played': 18, 'first_place': 0, 'secon...
# 244     Griffin  {'events_played': 26, 'first_place': 0, 'secon...
# 245     Kodaira  {'events_played': 18, 'first_place': 1, 'secon...
# 246       Every  {'events_played': 30, 'first_place': 0, 'secon...
# 247      Barnes  {'events_played': 22, 'first_place': 0, 'secon...
# 248        Hagy  {'events_played': 3, 'first_place': 0, 'second...
# 249       Couch  {'events_played': 5, 'first_place': 0, 'second...
# 250      Martin  {'events_played': 20, 'first_place': 0, 'secon...
# 251         Pan  {'events_played': 30, 'first_place': 0, 'secon...
# 252   Sabbatini  {'events_played': 27, 'first_place': 0, 'secon...
# 253   Streelman  {'events_played': 27, 'first_place': 0, 'secon...
# 254      Holmes  {'events_played': 24, 'first_place': 0, 'secon...
# 255    Matteson  {'events_played': 7, 'first_place': 0, 'second...
# 256      Langer  {'events_played': 2, 'first_place': 0, 'second...
# 257     Couples  {'events_played': 1, 'first_place': 0, 'second...
# 258     Micheel  {'events_played': 4, 'first_place': 0, 'second...
#
# [259 rows x 5 columns]
